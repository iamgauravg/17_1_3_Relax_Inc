# %%
import pandas as pd

# %%
file_path = r'1481069814_relax_challenge\relax_challenge\takehome_user_engagement.csv'
user_engagement_df = pd.read_csv(file_path)

user_engagement_df
# Out:
#                  time_stamp  user_id  visited
# 0       2014-04-22 03:53:30        1        1
# 1       2013-11-15 03:45:04        2        1
# 2       2013-11-29 03:45:04        2        1
# 3       2013-12-09 03:45:04        2        1
# 4       2013-12-25 03:45:04        2        1
# 5       2013-12-31 03:45:04        2        1
# 6       2014-01-08 03:45:04        2        1
# 7       2014-02-03 03:45:04        2        1
# 8       2014-02-08 03:45:04        2        1
# 9       2014-02-09 03:45:04        2        1
# 10      2014-02-13 03:45:04        2        1
# 11      2014-02-16 03:45:04        2        1
# 12      2014-03-09 03:45:04        2        1
# 13      2014-03-13 03:45:04        2        1
# 14      2014-03-31 03:45:04        2        1
# 15      2013-03-19 23:14:52        3        1
# 16      2013-05-22 08:09:28        4        1
# 17      2013-01-22 10:14:20        5        1
# 18      2013-12-19 03:37:06        6        1
# ...

# %%
user_engagement_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207917 entries, 0 to 207916
# Data columns (total 3 columns):
# time_stamp    207917 non-null object
# user_id       207917 non-null int64
# visited       207917 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 4.8+ MB

# %%
user_engagement_df.describe()
# Out:
#              user_id   visited
# count  207917.000000  207917.0
# mean     5913.314197       1.0
# std      3394.941674       0.0
# min         1.000000       1.0
# 25%      3087.000000       1.0
# 50%      5682.000000       1.0
# 75%      8944.000000       1.0
# max     12000.000000       1.0

# %%
user_engagement_df['time_stamp'] = pd.to_datetime(user_engagement_df['time_stamp'])

# %%
user_engagement_df.set_index(['user_id', 'time_stamp'], inplace=True)

# %%
user_engagement_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 207917 entries, (1, 2014-04-22 03:53:30) to (12000, 2014-01-26 08:57:12)
# Data columns (total 1 columns):
# visited    207917 non-null int64
# dtypes: int64(1)
# memory usage: 14.4 MB

# %%
user_engagement_df.groupby(level='user_id').apply(lambda x: x.rolling(window='1D', min_periods=1).min())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Miniconda2\envs\py36\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     917                                 levels=group_levels, names=group_names,
# --> 918                                 sort=False)
#     919             else:
#
# ~\Miniconda2\envs\py36\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     935
# --> 936     def _apply_filter(self, indices, dropna):
#     937         if len(indices) == 0:
#
# ~\Miniconda2\envs\py36\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, f, data, axis)
#
# <ipython-input-30-f034c28b3c56> in <lambda>(x)
# ----> 1 user_engagement_df.groupby(level='user_id').apply(lambda x: x.rolling(window='1D', min_periods=1).min())
#
# ...
